# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/soyeonhong/abdi/bias_audit_tool/sample_data/clinical_dataset_breast_cancer.csv")



for col in df.columns:
    print(col)
    print(df[col].value_counts())
    print("\n")
# Out:
# project.project_id
# project.project_id
# TCGA-BRCA    5546
# Name: count, dtype: int64
#
#
# cases.case_id
# cases.case_id
# c07b122e-ac50-4db2-add2-5617a5d0e976    40
# ccd4a24b-d8cc-4686-9dee-c98b0c5a8d21    33
# a8e7d8a4-bbf0-496b-b387-8e014cfdcea6    22
# deba32e4-0e68-4711-941b-3b63bd965afb    21
# 8d5fe6e8-d2cc-481f-a6a1-9cb6e7982cde    20
#                                         ..
# 452672e8-b6d9-45b5-bb02-e88e03e2dd66     1
# 281f70c5-876f-44b3-84fb-f2302f85e74c     1
# ad18820b-a804-49c0-ba8a-86c09fa6bce2     1
# ddcbdac6-9e43-4146-a611-d033125eba14     1
# 27b05b15-a44b-45ed-a6e3-e7d1ca488ea9     1
# Name: count, Length: 1098, dtype: int64
#
#
# cases.consent_type
# cases.consent_type
# Informed Consent    5427
# Consent by Death      59
# --                    55
# Consent Waiver         5
# Name: count, dtype: int64
#
#
# cases.days_to_consent
# cases.days_to_consent
# 0       575
# -1      258
# 7       145
# 31      134
# 14      122
#        ...
# 2972      3
# ...
